# %% [markdown]
# # EXAMEN SEA

# %%
import pandas as pd
import numpy as np

# %%
df4 = pd.read_excel('./EXAMEN301-changed/2014.xlsx')
df5 = pd.read_excel('./EXAMEN301-changed/2015.xlsx')
df6 = pd.read_excel('./EXAMEN301-changed/2016.xlsx')

df7 = pd.read_excel('./EXAMEN301-changed/2017.xlsx')
df8 = pd.read_excel('./EXAMEN301-changed/2018.xlsx')
df9 = pd.read_excel('./EXAMEN301-changed/2019.xlsx')

# %%
df4.head(2)
# df4.columns
# Out:
#                                              ENTIDAD  \
# 0   0901 Gobierno Autónomo Departamental de Chuqu...
# 1   0901 Gobierno Autónomo Departamental de Chuqu...
#
#                            CATEGORÍA PROGRAMÁTICA  \
# 0  95  0000  090  PROGRAMA DE SEGURIDAD CIUDADANA
# 1  95  0000  090  PROGRAMA DE SEGURIDAD CIUDADANA
#
#            FUENTE DE FINANCIAMIENTO  \
# 0  41  Tesoro General de la Nación
# 1  41  Tesoro General de la Nación
#
#                                ORGANISMO FINANCIADOR  \
# 0  119 T.G.N. - Impuesto Directo a los Hidrocarburos
# 1  119 T.G.N. - Impuesto Directo a los Hidrocarburos
#
#            GRUPO OBJETO DEL GASTO ACTIVIDAD / PROYECTO  PRESUPUESTO VIGENTE  \
# 0   20000 SERVICIOS NO PERSONALES          ACTIVIDADES            7367285.0
# 1  30000 MATERIALES Y SUMINISTROS          ACTIVIDADES            1069922.0
#
#    PRESUPUESTO EJECUTADO
# 0             2874608.12
# 1             1017455.55

# %%
df5.head(2)
# Out:
#                                              ENTIDAD  \
# 0   0901 Gobierno Autónomo Departamental de Chuqu...
# 1   0901 Gobierno Autónomo Departamental de Chuqu...
#
#                            CATEGORÍA PROGRAMÁTICA  \
# 0  95  0000  090  PROGRAMA DE SEGURIDAD CIUDADANA
# 1  95  0000  090  PROGRAMA DE SEGURIDAD CIUDADANA
#
#            FUENTE DE FINANCIAMIENTO  \
# 0  41  Tesoro General de la Nación
# 1  41  Tesoro General de la Nación
#
#                                ORGANISMO FINANCIADOR  \
# 0  119 T.G.N. - Impuesto Directo a los Hidrocarburos
# 1  119 T.G.N. - Impuesto Directo a los Hidrocarburos
#
#            GRUPO OBJETO DEL GASTO ACTIVIDAD / PROYECTO  PRESUPUESTO VIGENTE  \
# 0   20000 SERVICIOS NO PERSONALES          ACTIVIDADES            2802388.0
# 1  30000 MATERIALES Y SUMINISTROS          ACTIVIDADES            1304582.0
#
#    PRESUPUESTO EJECUTADO
# 0             2690408.27
# 1              986863.15

# %%
df6.head(2)
# Out:
#                                              ENTIDAD  \
# 0   0901 Gobierno Autónomo Departamental de Chuqu...
# 1   0901 Gobierno Autónomo Departamental de Chuqu...
#
#                             CATEGORÍA PROGRAMÁTICA  \
# 0  95  0000  090  PROGRAMA DE SEGURIDAD CIUDADANA
# 1  95  0000  090  PROGRAMA DE SEGURIDAD CIUDADANA
#
#            FUENTE DE FINANCIAMIENTO  \
# 0  41  Tesoro General de la Nación
# 1  41  Tesoro General de la Nación
#
#                                ORGANISMO FINANCIADOR  \
# 0  119 T.G.N. - Impuesto Directo a los Hidrocarburos
# 1  119 T.G.N. - Impuesto Directo a los Hidrocarburos
#
#            GRUPO OBJETO DEL GASTO ACTIVIDAD / PROYECTO  PRESUPUESTO VIGENTE  \
# 0   20000 SERVICIOS NO PERSONALES          ACTIVIDADES           2436751.24
# 1  30000 MATERIALES Y SUMINISTROS          ACTIVIDADES            727745.76
#
#    PRESUPUESTO EJECUTADO
# 0             2413713.14
# 1              715624.50

# %%
df7.head(2)
# Out:
#                                              ENTIDAD  \
# 0   0901 Gobierno Autónomo Departamental de Chuqu...
# 1  0901 Gobierno Autónomo Departamental de Chuqui...
#
#                             CATEGORÍA PROGRAMÁTICA  \
# 0  95  0000  090  PROGRAMA DE SEGURIDAD CIUDADANA
# 1   95  0000  090  PROGRAMA DE SEGURIDAD CIUDADANA
#
#            FUENTE DE FINANCIAMIENTO  \
# 0  41  Tesoro General de la Nación
# 1   41  Tesoro General de la Nación
#
#                                ORGANISMO FINANCIADOR  \
# 0  119 T.G.N. - Impuesto Directo a los Hidrocarburos
# 1  119 T.G.N. - Impuesto Directo a los Hidrocarburos
#
#            GRUPO OBJETO DEL GASTO ACTIVIDAD / PROYECTO  PRESUPUESTO VIGENTE  \
# 0   20000 SERVICIOS NO PERSONALES          ACTIVIDADES            1542959.0
# 1  30000 MATERIALES Y SUMINISTROS          ACTIVIDADES             821805.0
#
#    PRESUPUESTO EJECUTADO
# 0             1520311.92
# 1              818161.25

# %%
df8.head(2)
# Out:
#                                              ENTIDAD  \
# 0   0901 Gobierno Autónomo Departamental de Chuqu...
# 1   0901 Gobierno Autónomo Departamental de Chuqu...
#
#                             CATEGORÍA PROGRAMÁTICA  \
# 0  95  0000  090  PROGRAMA DE SEGURIDAD CIUDADANA
# 1  95  0000  090  PROGRAMA DE SEGURIDAD CIUDADANA
#
#            FUENTE DE FINANCIAMIENTO  \
# 0  41  Tesoro General de la Nación
# 1  41  Tesoro General de la Nación
#
#                                ORGANISMO FINANCIADOR  \
# 0  119 T.G.N. - Impuesto Directo a los Hidrocarburos
# 1  119 T.G.N. - Impuesto Directo a los Hidrocarburos
#
#            GRUPO OBJETO DEL GASTO ACTIVIDAD / PROYECTO  PRESUPUESTO VIGENTE  \
# 0   20000 SERVICIOS NO PERSONALES          ACTIVIDADES             909327.0
# 1  30000 MATERIALES Y SUMINISTROS          ACTIVIDADES             945918.0
#
#    PRESUPUESTO EJECUTADO
# 0              863425.62
# 1              912776.40

# %%
df9.head(2)
# Out:
#                                              ENTIDAD  \
# 0   0901 Gobierno Autónomo Departamental de Chuqu...
# 1   0901 Gobierno Autónomo Departamental de Chuqu...
#
#                          CATEGORÍA PROGRAMÁTICA  \
# 0  95  0  090  PROGRAMA DE SEGURIDAD CIUDADANA
# 1  95  0  090  PROGRAMA DE SEGURIDAD CIUDADANA
#
#            FUENTE DE FINANCIAMIENTO  \
# 0  41  Tesoro General de la Nación
# 1  41  Tesoro General de la Nación
#
#                                ORGANISMO FINANCIADOR  \
# 0  119 T.G.N. - Impuesto Directo a los Hidrocarburos
# 1  119 T.G.N. - Impuesto Directo a los Hidrocarburos
#
#           GRUPO OBJETO DEL GASTO                    OBJETO DEL GASTO  \
# 0  20000 SERVICIOS NO PERSONALES             21200 Energía Eléctrica
# 1  20000 SERVICIOS NO PERSONALES  22110 Pasajes al Interior del País
#
#   ACTIVIDAD / PROYECTO  PRESUPUESTO INICIAL  MODIFICACIONES  \
# 0          ACTIVIDADES                75000             0.0
# ...

# %%
print(df4.columns,'\n')
print(df5.columns,'\n')
print(df6.columns,'\n')
print(df7.columns,'\n')
print(df8.columns,'\n')
print(df9.columns,'\n')
# Out:
# Index(['ENTIDAD', 'CATEGORÍA PROGRAMÁTICA', 'FUENTE DE FINANCIAMIENTO',
#        'ORGANISMO FINANCIADOR', 'GRUPO OBJETO DEL GASTO',
#        'ACTIVIDAD / PROYECTO', 'PRESUPUESTO VIGENTE', 'PRESUPUESTO EJECUTADO'],
#       dtype='object')
#
# Index(['ENTIDAD', 'CATEGORÍA PROGRAMÁTICA', 'FUENTE DE FINANCIAMIENTO',
#        'ORGANISMO FINANCIADOR', 'GRUPO OBJETO DEL GASTO',
#        'ACTIVIDAD / PROYECTO', 'PRESUPUESTO VIGENTE', 'PRESUPUESTO EJECUTADO'],
#       dtype='object')
#
# Index(['ENTIDAD', 'CATEGORÍA PROGRAMÁTICA', 'FUENTE DE FINANCIAMIENTO',
#        'ORGANISMO FINANCIADOR', 'GRUPO OBJETO DEL GASTO',
#        'ACTIVIDAD / PROYECTO', 'PRESUPUESTO VIGENTE', 'PRESUPUESTO EJECUTADO'],
#       dtype='object')
#
# Index(['ENTIDAD', 'CATEGORÍA PROGRAMÁTICA', 'FUENTE DE FINANCIAMIENTO',
#        'ORGANISMO FINANCIADOR', 'GRUPO OBJETO DEL GASTO',
#        'ACTIVIDAD / PROYECTO', 'PRESUPUESTO VIGENTE', 'PRESUPUESTO EJECUTADO'],
#       dtype='object')
#
# ...

# %%
print(df4.shape,'\n')
print(df5.shape,'\n')
print(df6.shape,'\n')
print(df7.shape,'\n')
print(df8.shape,'\n')
print(df9.shape,'\n')
# Out:
# (2600, 8)
#
# (2122, 8)
#
# (2034, 8)
#
# (1920, 8)
#
# (2227, 8)
#
# (4795, 11)

# %% [markdown]
# ## concatenando

# %% [markdown]
# ### Pregunta 1

# %%
DF = pd.concat([df4, df5, df6, df7, df8, df9],sort=False, axis=0)

# %%
DF.head(3)
# Out:
#                                              ENTIDAD  \
# 0   0901 Gobierno Autónomo Departamental de Chuqu...
# 1   0901 Gobierno Autónomo Departamental de Chuqu...
# 2   0901 Gobierno Autónomo Departamental de Chuqu...
#
#                            CATEGORÍA PROGRAMÁTICA  \
# 0  95  0000  090  PROGRAMA DE SEGURIDAD CIUDADANA
# 1  95  0000  090  PROGRAMA DE SEGURIDAD CIUDADANA
# 2  95  0000  090  PROGRAMA DE SEGURIDAD CIUDADANA
#
#            FUENTE DE FINANCIAMIENTO  \
# 0  41  Tesoro General de la Nación
# 1  41  Tesoro General de la Nación
# 2  41  Tesoro General de la Nación
#
#                                ORGANISMO FINANCIADOR  \
# 0  119 T.G.N. - Impuesto Directo a los Hidrocarburos
# 1  119 T.G.N. - Impuesto Directo a los Hidrocarburos
# 2  119 T.G.N. - Impuesto Directo a los Hidrocarburos
#
#            GRUPO OBJETO DEL GASTO ACTIVIDAD / PROYECTO  PRESUPUESTO VIGENTE  \
# 0   20000 SERVICIOS NO PERSONALES          ACTIVIDADES            7367285.0
# ...

# %%
DF.shape
# Out:
# (15698, 11)

# %%
# print(df8.columns, '\n')
# print(df9.columns, '\n')

# %% [markdown]
# ### Pregunta 2

# %%
DF['CATEGORÍA PROGRAMÁTICA'] = DF.apply(lambda row: str(row['CATEGORÍA PROGRAMÁTICA']).strip(' '), axis=1)
DF.head(4)
# Out:
#                                              ENTIDAD  \
# 0   0901 Gobierno Autónomo Departamental de Chuqu...
# 1   0901 Gobierno Autónomo Departamental de Chuqu...
# 2   0901 Gobierno Autónomo Departamental de Chuqu...
# 3   0901 Gobierno Autónomo Departamental de Chuqu...
#
#                               CATEGORÍA PROGRAMÁTICA  \
# 0     95  0000  090  PROGRAMA DE SEGURIDAD CIUDADANA
# 1     95  0000  090  PROGRAMA DE SEGURIDAD CIUDADANA
# 2     95  0000  090  PROGRAMA DE SEGURIDAD CIUDADANA
# 3  95  0035  000  CONST. ESTACION POLICIAL INTEGR...
#
#            FUENTE DE FINANCIAMIENTO  \
# 0  41  Tesoro General de la Nación
# 1  41  Tesoro General de la Nación
# 2  41  Tesoro General de la Nación
# 3  41  Tesoro General de la Nación
#
#                                ORGANISMO FINANCIADOR  \
# 0  119 T.G.N. - Impuesto Directo a los Hidrocarburos
# 1  119 T.G.N. - Impuesto Directo a los Hidrocarburos
# 2  119 T.G.N. - Impuesto Directo a los Hidrocarburos
# ...

# %%
# pregunta 3

DF['CATEGORÍA PROGRAMÁTICA'] = DF.apply (lambda row: (' '.join(str(row['CATEGORÍA PROGRAMÁTICA']).split())), axis=1)
DF.head()
# Out:
#                                              ENTIDAD  \
# 0   0901 Gobierno Autónomo Departamental de Chuqu...
# 1   0901 Gobierno Autónomo Departamental de Chuqu...
# 2   0901 Gobierno Autónomo Departamental de Chuqu...
# 3   0901 Gobierno Autónomo Departamental de Chuqu...
# 4     0902 Gobierno Autónomo Departamental de La Paz
#
#                               CATEGORÍA PROGRAMÁTICA  \
# 0        95 0000 090 PROGRAMA DE SEGURIDAD CIUDADANA
# 1        95 0000 090 PROGRAMA DE SEGURIDAD CIUDADANA
# 2        95 0000 090 PROGRAMA DE SEGURIDAD CIUDADANA
# 3  95 0035 000 CONST. ESTACION POLICIAL INTEGRADA...
# 4        95 0000 090 PROGRAMA DE SEGURIDAD CIUDADANA
#
#            FUENTE DE FINANCIAMIENTO  \
# 0  41  Tesoro General de la Nación
# 1  41  Tesoro General de la Nación
# 2  41  Tesoro General de la Nación
# 3  41  Tesoro General de la Nación
# 4  41  Tesoro General de la Nación
#
#                                ORGANISMO FINANCIADOR  \
# ...

# %% [markdown]
# ### Pregunta 4

# %%
DF['PROGRAMA'],DF['PROYECTO'], DF['ACTIVIDAD'], DF['CATEGORÍA PROGRAMÁTICA'] = DF['CATEGORÍA PROGRAMÁTICA'].str.split(' ', 3).str
DF.head(3)
# Out:
#                                              ENTIDAD  \
# 0   0901 Gobierno Autónomo Departamental de Chuqu...
# 1   0901 Gobierno Autónomo Departamental de Chuqu...
# 2   0901 Gobierno Autónomo Departamental de Chuqu...
#
#             CATEGORÍA PROGRAMÁTICA          FUENTE DE FINANCIAMIENTO  \
# 0  PROGRAMA DE SEGURIDAD CIUDADANA  41  Tesoro General de la Nación
# 1  PROGRAMA DE SEGURIDAD CIUDADANA  41  Tesoro General de la Nación
# 2  PROGRAMA DE SEGURIDAD CIUDADANA  41  Tesoro General de la Nación
#
#                                ORGANISMO FINANCIADOR  \
# 0  119 T.G.N. - Impuesto Directo a los Hidrocarburos
# 1  119 T.G.N. - Impuesto Directo a los Hidrocarburos
# 2  119 T.G.N. - Impuesto Directo a los Hidrocarburos
#
#            GRUPO OBJETO DEL GASTO ACTIVIDAD / PROYECTO  PRESUPUESTO VIGENTE  \
# 0   20000 SERVICIOS NO PERSONALES          ACTIVIDADES            7367285.0
# 1  30000 MATERIALES Y SUMINISTROS          ACTIVIDADES            1069922.0
# ...

# %% [markdown]
# ### Pregunta 5

# %%
DF['ENTIDAD'] = DF.apply(lambda row: str(row['ENTIDAD']).strip(' '), axis=1)
DF.head(4)
# Out:
#                                              ENTIDAD  \
# 0  0901 Gobierno Autónomo Departamental de Chuqui...
# 1  0901 Gobierno Autónomo Departamental de Chuqui...
# 2  0901 Gobierno Autónomo Departamental de Chuqui...
# 3  0901 Gobierno Autónomo Departamental de Chuqui...
#
#                               CATEGORÍA PROGRAMÁTICA  \
# 0                    PROGRAMA DE SEGURIDAD CIUDADANA
# 1                    PROGRAMA DE SEGURIDAD CIUDADANA
# 2                    PROGRAMA DE SEGURIDAD CIUDADANA
# 3  CONST. ESTACION POLICIAL INTEGRADA PATACON - S...
#
#            FUENTE DE FINANCIAMIENTO  \
# 0  41  Tesoro General de la Nación
# 1  41  Tesoro General de la Nación
# 2  41  Tesoro General de la Nación
# 3  41  Tesoro General de la Nación
#
#                                ORGANISMO FINANCIADOR  \
# 0  119 T.G.N. - Impuesto Directo a los Hidrocarburos
# 1  119 T.G.N. - Impuesto Directo a los Hidrocarburos
# 2  119 T.G.N. - Impuesto Directo a los Hidrocarburos
# ...

# %% [markdown]
# ### ENTIDAD

# %%
DF['CODIGO_ENTIDAD'],DF['ENTIDAD'] = DF['ENTIDAD'].str.split(' ', 1).str
DF.head(3)
# Out:
#                                          ENTIDAD  \
# 0  Gobierno Autónomo Departamental de Chuquisaca
# 1  Gobierno Autónomo Departamental de Chuquisaca
# 2  Gobierno Autónomo Departamental de Chuquisaca
#
#             CATEGORÍA PROGRAMÁTICA          FUENTE DE FINANCIAMIENTO  \
# 0  PROGRAMA DE SEGURIDAD CIUDADANA  41  Tesoro General de la Nación
# 1  PROGRAMA DE SEGURIDAD CIUDADANA  41  Tesoro General de la Nación
# 2  PROGRAMA DE SEGURIDAD CIUDADANA  41  Tesoro General de la Nación
#
#                                ORGANISMO FINANCIADOR  \
# 0  119 T.G.N. - Impuesto Directo a los Hidrocarburos
# 1  119 T.G.N. - Impuesto Directo a los Hidrocarburos
# 2  119 T.G.N. - Impuesto Directo a los Hidrocarburos
#
#            GRUPO OBJETO DEL GASTO ACTIVIDAD / PROYECTO  PRESUPUESTO VIGENTE  \
# 0   20000 SERVICIOS NO PERSONALES          ACTIVIDADES            7367285.0
# 1  30000 MATERIALES Y SUMINISTROS          ACTIVIDADES            1069922.0
# ...

# %% [markdown]
# ### FUENTE DE FINANCIAMIENTO

# %%
DF['FUENTE DE FINANCIAMIENTO'] = DF.apply(lambda row: str(row['FUENTE DE FINANCIAMIENTO']).strip(' '), axis=1)
DF.head(4)
# Out:
#                                          ENTIDAD  \
# 0  Gobierno Autónomo Departamental de Chuquisaca
# 1  Gobierno Autónomo Departamental de Chuquisaca
# 2  Gobierno Autónomo Departamental de Chuquisaca
# 3  Gobierno Autónomo Departamental de Chuquisaca
#
#                               CATEGORÍA PROGRAMÁTICA  \
# 0                    PROGRAMA DE SEGURIDAD CIUDADANA
# 1                    PROGRAMA DE SEGURIDAD CIUDADANA
# 2                    PROGRAMA DE SEGURIDAD CIUDADANA
# 3  CONST. ESTACION POLICIAL INTEGRADA PATACON - S...
#
#           FUENTE DE FINANCIAMIENTO  \
# 0  41  Tesoro General de la Nación
# 1  41  Tesoro General de la Nación
# 2  41  Tesoro General de la Nación
# 3  41  Tesoro General de la Nación
#
#                                ORGANISMO FINANCIADOR  \
# 0  119 T.G.N. - Impuesto Directo a los Hidrocarburos
# 1  119 T.G.N. - Impuesto Directo a los Hidrocarburos
# 2  119 T.G.N. - Impuesto Directo a los Hidrocarburos
# ...

# %%
DF['CODIGO_fDeFinanciamiento'],DF['FUENTE DE FINANCIAMIENTO'] = DF['FUENTE DE FINANCIAMIENTO'].str.split(' ', 1).str
DF.head(3)
# Out:
#                                          ENTIDAD  \
# 0  Gobierno Autónomo Departamental de Chuquisaca
# 1  Gobierno Autónomo Departamental de Chuquisaca
# 2  Gobierno Autónomo Departamental de Chuquisaca
#
#             CATEGORÍA PROGRAMÁTICA      FUENTE DE FINANCIAMIENTO  \
# 0  PROGRAMA DE SEGURIDAD CIUDADANA   Tesoro General de la Nación
# 1  PROGRAMA DE SEGURIDAD CIUDADANA   Tesoro General de la Nación
# 2  PROGRAMA DE SEGURIDAD CIUDADANA   Tesoro General de la Nación
#
#                                ORGANISMO FINANCIADOR  \
# 0  119 T.G.N. - Impuesto Directo a los Hidrocarburos
# 1  119 T.G.N. - Impuesto Directo a los Hidrocarburos
# 2  119 T.G.N. - Impuesto Directo a los Hidrocarburos
#
#            GRUPO OBJETO DEL GASTO ACTIVIDAD / PROYECTO  PRESUPUESTO VIGENTE  \
# 0   20000 SERVICIOS NO PERSONALES          ACTIVIDADES            7367285.0
# 1  30000 MATERIALES Y SUMINISTROS          ACTIVIDADES            1069922.0
# ...

# %% [markdown]
# ### GRUPO OBJETO DEL GASTO

# %%
DF['GRUPO OBJETO DEL GASTO'] = DF.apply(lambda row: str(row['GRUPO OBJETO DEL GASTO']).strip(' '), axis=1)
DF.head(4)

# %%
DF['CODIGO_gObjGasto'],DF['GRUPO OBJETO DEL GASTO'] = DF['GRUPO OBJETO DEL GASTO'].str.split(' ', 1).str
DF.head(3)
# Out:
#                                          ENTIDAD  \
# 0  Gobierno Autónomo Departamental de Chuquisaca
# 1  Gobierno Autónomo Departamental de Chuquisaca
# 2  Gobierno Autónomo Departamental de Chuquisaca
#
#             CATEGORÍA PROGRAMÁTICA      FUENTE DE FINANCIAMIENTO  \
# 0  PROGRAMA DE SEGURIDAD CIUDADANA   Tesoro General de la Nación
# 1  PROGRAMA DE SEGURIDAD CIUDADANA   Tesoro General de la Nación
# 2  PROGRAMA DE SEGURIDAD CIUDADANA   Tesoro General de la Nación
#
#                                ORGANISMO FINANCIADOR  \
# 0  119 T.G.N. - Impuesto Directo a los Hidrocarburos
# 1  119 T.G.N. - Impuesto Directo a los Hidrocarburos
# 2  119 T.G.N. - Impuesto Directo a los Hidrocarburos
#
#      GRUPO OBJETO DEL GASTO ACTIVIDAD / PROYECTO  PRESUPUESTO VIGENTE  \
# 0   SERVICIOS NO PERSONALES          ACTIVIDADES            7367285.0
# 1  MATERIALES Y SUMINISTROS          ACTIVIDADES            1069922.0
# 2            ACTIVOS REALES          ACTIVIDADES            5656775.0
#
# ...

# %% [markdown]
# ### ORGANISMO FINANCIADOR

# %%
DF['ORGANISMO FINANCIADOR'] = DF.apply(lambda row: str(row['ORGANISMO FINANCIADOR']).strip(' '), axis=1)
DF.head(4)

# %%
DF['CODIGO_OrgFin'],DF['ORGANISMO FINANCIADOR'] = DF['ORGANISMO FINANCIADOR'].str.split(' ', 1).str
DF.head(3)
# Out:
#                                          ENTIDAD  \
# 0  Gobierno Autónomo Departamental de Chuquisaca
# 1  Gobierno Autónomo Departamental de Chuquisaca
# 2  Gobierno Autónomo Departamental de Chuquisaca
#
#             CATEGORÍA PROGRAMÁTICA      FUENTE DE FINANCIAMIENTO  \
# 0  PROGRAMA DE SEGURIDAD CIUDADANA   Tesoro General de la Nación
# 1  PROGRAMA DE SEGURIDAD CIUDADANA   Tesoro General de la Nación
# 2  PROGRAMA DE SEGURIDAD CIUDADANA   Tesoro General de la Nación
#
#                            ORGANISMO FINANCIADOR    GRUPO OBJETO DEL GASTO  \
# 0  T.G.N. - Impuesto Directo a los Hidrocarburos   SERVICIOS NO PERSONALES
# 1  T.G.N. - Impuesto Directo a los Hidrocarburos  MATERIALES Y SUMINISTROS
# 2  T.G.N. - Impuesto Directo a los Hidrocarburos            ACTIVOS REALES
#
#   ACTIVIDAD / PROYECTO  PRESUPUESTO VIGENTE  PRESUPUESTO EJECUTADO  \
# 0          ACTIVIDADES            7367285.0             2874608.12
# ...

# %% [markdown]
# ### pregunta 6

# %% [markdown]
# ### pregunta 7
